# %%
import pymysql
import tweepy
import json
import mysql.connector
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

conexion1=mysql.connector.connect(host="localhost",user="root",port="3307",password="4aneYUBuG1JgfHa",database="prueba1")

cursor1= conexion1.cursor()

#user = api.get_user(screen_name= "German_Vargas")


for status in tweepy.Cursor(api.user_timeline, screen_name = 'petrogustavo', exclude_replies = True, include_rts = False, tweet_mode="extended").items(1000):
#Variables    
    full_text = status.full_text
    created_at = status.created_at
    favorite_count = status.favorite_count
    retweet_count = status.retweet_count
    print(full_text)
    
    sql="insert into twets_candidatos(tweet, candidato, fecha_creacion, numero_favoritos, numero_retweets) values (%s,%s,%s,%s,%s)"
#envio de datos
    datos=(full_text, "Gustavo Petro", created_at, favorite_count, retweet_count)
    cursor1.execute(sql, datos)
    
conexion1.commit()
conexion1.close() 

#Captura tomada en 03 de febrero 5:40 pm
# Out:
# Hice el compromiso de no comentar públicamente mi conversación con el Papa Francisco del que ya he leído sus dos encíclicas: "Laudato Si" y "Fratelli Tutti" que les recomiendo.
#
# La absolución de un dirigente político siempre pasará por su compromiso profundo con el pueblo https://t.co/OEn1Sc9dt8
# Las voces campesinas son muchísimo más sabias que los magísteres de economía de Bogotá que han llevado al país al borde la hambruna. https://t.co/bgM0OqsbRy
# La mentalidad paramilitar de los gobernantes termina expresada en una política de seguridad basada en el número de muertes.
#
# Por eso hubo 6.402 jóvenes inocentes fusilados por el gobierno entre 2003 y 2010, y casi de un centenar de manifestantes asesinados en el gobierno de Duque https://t.co/x50gk6PPf9
# A una mujer trabajadora. A quien dedicó su vida al trabajo y el arte, al saber del cerebro y a la sensibilidad del corazón.
#
# Escuchaba, de niño, su nombre en la radio, ahora, mi humilde homenaje a toda una mujer.
#
# ...

# %%
import pymysql
import tweepy
import json
import mysql.connector
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

conexion1=mysql.connector.connect(host="localhost",user="root",port="3307",password="4aneYUBuG1JgfHa",database="prueba1")

cursor1= conexion1.cursor()



for status in tweepy.Cursor(api.user_timeline, screen_name = 'FicoGutierrez', exclude_replies = True, include_rts = False, tweet_mode="extended").items(100):
#Variables    
    full_text = status.full_text
    created_at = status.created_at
    favorite_count = status.favorite_count
    retweet_count = status.retweet_count
    #print(full_text)
    print('FINALIZADO')
    
    sql="insert into twets_candidatos(tweet, candidato, fecha_creacion, numero_favoritos, numero_retweets) values (%s,%s,%s,%s,%s)"
#envio de datos
    datos=(full_text, "Federico Gutiérrez", created_at, favorite_count, retweet_count)
    cursor1.execute(sql, datos)
    
conexion1.commit()
conexion1.close() 

#Captura tomada en 03 de febrero 5:40 pm
# Out:
# FINALIZADO
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-2-32a3c6ded6cc> in <module>
#      29 #envio de datos
#      30     datos=(full_text, "Federico Gutiérrez", created_at, favorite_count, retweet_count)
# ---> 31     cursor1.execute(sql, datos)
#      32
#      33 conexion1.commit()
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     549         else:
#     550             try:
# --> 551                 self._handle_result(self._connection.cmd_query(stmt))
#     552             except errors.InterfaceError:
#     553                 if self._connection._have_next_result:  # pylint: disable=W0212
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     488         if not isinstance(query, bytes):
# ...

# %%
import csv
import tweepy

#import mysql.connector
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

D_usuario = []
D_tweet = []
D_numero_retweet = []
D_numero_favoritos = []
D_fecha_creaccion = []

keyword = input("Enter Keyweord/Tag to search about: ")
cantidad= int(input("Enter how many tweets to search: "))
n_f_min= 10
for tweet in tweepy.Cursor(api.search_tweets, q=keyword).items(cantidad):
    if tweet.retweet_count > n_f_min:
        screen_name= tweet.user.screen_name
        full_text = tweet.text
        retweet_count = tweet.retweet_count
        favorite_count = tweet.favorite_count
        created_at = tweet.created_at

        D_usuario.append(screen_name)
        D_tweet.append(full_text)
        D_numero_retweet.append(retweet_count)
        D_numero_favoritos.append(favorite_count)
        D_fecha_creaccion.append(created_at)
            
    
        #print("El texto es: \n" + tweet.text)
        #print("la feacha de creacion: \n" +str(tweet.created_at))
        #print("Numero de favoritos: " + str(tweet.favorite_count))
        #print("El numero de retweets: " + str(tweet.retweet_count))
        #print("Las cordenadas del tweet: " + str(tweet.coordinates))
        #print("Usuario: " + str(tweet.user.screen_name))

if len(D_tweet) > 0 : 
        with open('Mencionespetro.csv', 'w', newline='',encoding="utf-8") as f:
            fieldnames = ['usuario', 'tweet', 'numero_retweet', 'numero_favoritos', 'fecha_creaccion']
            writer = csv.DictWriter(f,delimiter= ",", fieldnames=fieldnames)
            writer.writeheader()
            for i, text in enumerate(D_tweet):
                 writer.writerow({'usuario':  D_usuario[i], 'tweet' : D_tweet[i], 'numero_retweet' : D_numero_retweet[i], 'numero_favoritos': D_numero_favoritos[i], 'fecha_creaccion' :D_fecha_creaccion[i]})



print("fin")
#Captura tomada en 03 de febrero 5:40 pm
# Out:
# Enter Keyweord/Tag to search about:  @petrogustavo
# Enter how many tweets to search:  10
# fin

# %%
import csv
import tweepy

#import mysql.connector
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

D_tweet = []
D_candidato = []
D_fecha_creacion = []
D_numero_favoritos = []
D_numero_retweets = []

for status in tweepy.Cursor(api.user_timeline, screen_name = 'agaviriau', exclude_replies = True, include_rts = False, tweet_mode="extended").items(1000):
    screen_name = "Alejandro Gaviria"
    full_text = status.full_text
    created_at = status.created_at
    favorite_count = status.favorite_count
    retweet_count = status.retweet_count

    D_tweet.append(full_text)
    D_candidato.append(screen_name)
    D_fecha_creacion.append(created_at)
    D_numero_favoritos.append(favorite_count)
    D_numero_retweets.append(retweet_count)


if len(D_tweet) > 0 : 
        with open('Alejandro Gaviria.csv', 'w', newline='',encoding="utf-8") as f:
            fieldnames = ['tweet', 'candidato', 'fecha_creacion', 'numero_favoritos', 'numero_retweets']
            writer = csv.DictWriter(f,delimiter= ",", fieldnames=fieldnames)
            writer.writeheader()
            for i, text in enumerate(D_tweet):
                 writer.writerow({'tweet': D_tweet[i], 'candidato' : D_candidato[i], 'fecha_creacion' : D_fecha_creacion[i], 'numero_favoritos': D_numero_favoritos[i], 'numero_retweets' :D_numero_retweets[i]})



print("fin")
#Captura tomada en 03 de febrero 5:40 pm
# Out:
# fin

# %%
import csv
import tweepy

#import mysql.connector
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

D_tweet = []
D_candidato = []
D_fecha_creacion = []
D_numero_favoritos = []
D_numero_retweets = []

for status in tweepy.Cursor(api.user_timeline, screen_name = 'FranciaMarquezM', exclude_replies = True, include_rts = False, tweet_mode="extended").items(1000):
    screen_name = "Francia Márquez Mina"
    full_text = status.full_text
    created_at = status.created_at
    favorite_count = status.favorite_count
    retweet_count = status.retweet_count

    D_tweet.append(full_text)
    D_candidato.append(screen_name)
    D_fecha_creacion.append(created_at)
    D_numero_favoritos.append(favorite_count)
    D_numero_retweets.append(retweet_count)


if len(D_tweet) > 0 : 
        with open('Francia Márquez Mina.csv', 'w', newline='',encoding="utf-8") as f:
            fieldnames = ['tweet', 'candidato', 'fecha_creacion', 'numero_favoritos', 'numero_retweets']
            writer = csv.DictWriter(f,delimiter= ",", fieldnames=fieldnames)
            writer.writeheader()
            for i, text in enumerate(D_tweet):
                 writer.writerow({'tweet': D_tweet[i], 'candidato' : D_candidato[i], 'fecha_creacion' : D_fecha_creacion[i], 'numero_favoritos': D_numero_favoritos[i], 'numero_retweets' :D_numero_retweets[i]})



print("fin")
#Captura tomada en 03 de febrero 5:40 pm
# Out:
# fin

# %%
import pymysql
import tweepy
import json
import mysql.connector
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

conexion1=mysql.connector.connect(host="localhost",user="root",port="3307",password="4aneYUBuG1JgfHa",database="prueba1")

cursor1= conexion1.cursor()

#user = api.get_user(screen_name= "German_Vargas")


for status in tweepy.Cursor(api.user_timeline, screen_name = 'OIZuluaga', exclude_replies = True, include_rts = False, tweet_mode="extended").items(1000):
#Variables    
    full_text = status.full_text
    created_at = status.created_at
    favorite_count = status.favorite_count
    retweet_count = status.retweet_count
    print(full_text)
    
    sql="insert into twets_candidatos(tweet, candidato, fecha_creacion, numero_favoritos, numero_retweets) values (%s,%s,%s,%s,%s)"
#envio de datos
    datos=(full_text, "Óscar Iván Zuluaga", created_at, favorite_count, retweet_count)
    cursor1.execute(sql, datos)
    
conexion1.commit()
conexion1.close() 

#Captura tomada en 22 de enero 7:40 pm

# %%
import csv
import tweepy

#import mysql.connector
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

D_tweet = []
D_candidato = []
D_fecha_creacion = []
D_numero_favoritos = []
D_numero_retweets = []

for status in tweepy.Cursor(api.user_timeline, screen_name = 'OIZuluaga', exclude_replies = True, include_rts = False, tweet_mode="extended").items(1000):
    screen_name = "Óscar Iván Zuluaga"
    full_text = status.full_text
    created_at = status.created_at
    favorite_count = status.favorite_count
    retweet_count = status.retweet_count

    D_tweet.append(full_text)
    D_candidato.append(screen_name)
    D_fecha_creacion.append(created_at)
    D_numero_favoritos.append(favorite_count)
    D_numero_retweets.append(retweet_count)


if len(D_tweet) > 0 : 
        with open('Óscar Iván Zuluaga.csv', 'w', newline='',encoding="utf-8") as f:
            fieldnames = ['tweet', 'candidato', 'fecha_creacion', 'numero_favoritos', 'numero_retweets']
            writer = csv.DictWriter(f,delimiter= ",", fieldnames=fieldnames)
            writer.writeheader()
            for i, text in enumerate(D_tweet):
                 writer.writerow({'tweet': D_tweet[i], 'candidato' : D_candidato[i], 'fecha_creacion' : D_fecha_creacion[i], 'numero_favoritos': D_numero_favoritos[i], 'numero_retweets' :D_numero_retweets[i]})



print("fin")
#Captura tomada en 03 de febrero 5:40 pm
# Out:
# fin

# %%
import csv
import tweepy

#import mysql.connector
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

D_tweet = []
D_candidato = []
D_fecha_creacion = []
D_numero_favoritos = []
D_numero_retweets = []

for status in tweepy.Cursor(api.user_timeline, screen_name = 'ingrodolfohdez', exclude_replies = True, include_rts = False, tweet_mode="extended").items(1000):
    screen_name = "Ing Rodolfo Hernandez"
    full_text = status.full_text
    created_at = status.created_at
    favorite_count = status.favorite_count
    retweet_count = status.retweet_count

    D_tweet.append(full_text)
    D_candidato.append(screen_name)
    D_fecha_creacion.append(created_at)
    D_numero_favoritos.append(favorite_count)
    D_numero_retweets.append(retweet_count)


if len(D_tweet) > 0 : 
        with open('Ing Rodolfo Hernandez.csv', 'w', newline='',encoding="utf-8") as f:
            fieldnames = ['tweet', 'candidato', 'fecha_creacion', 'numero_favoritos', 'numero_retweets']
            writer = csv.DictWriter(f,delimiter= ",", fieldnames=fieldnames)
            writer.writeheader()
            for i, text in enumerate(D_tweet):
                 writer.writerow({'tweet': D_tweet[i], 'candidato' : D_candidato[i], 'fecha_creacion' : D_fecha_creacion[i], 'numero_favoritos': D_numero_favoritos[i], 'numero_retweets' :D_numero_retweets[i]})



print("fin")
#Captura tomada en 03 de febrero 5:40 pm

# %%
import pymysql
import tweepy
import json
import mysql.connector
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

conexion1=mysql.connector.connect(host="localhost",user="root",port="3307",password="4aneYUBuG1JgfHa",database="prueba1")

cursor1= conexion1.cursor()

user = api.get_user(screen_name= "German_Vargas")


for status in tweepy.Cursor(api.user_timeline, screen_name = 'sergio_fajardo', exclude_replies = True, include_rts = False, tweet_mode="extended").items(1000):
#Variables    
    full_text = status.full_text
    created_at = status.created_at
    favorite_count = status.favorite_count
    retweet_count = status.retweet_count
    #print(full_text)
    print('FINALIZADO')
    
    sql="insert into twets_candidatos(tweet, candidato, fecha_creacion, numero_favoritos, numero_retweets) values (%s,%s,%s,%s,%s)"
#envio de datos
    datos=(full_text, "Sergio Fajardo", created_at, favorite_count, retweet_count)
    cursor1.execute(sql, datos)
    
conexion1.commit()
conexion1.close() 

#Captura tomada en 03 de febrero 5:40 pm

# %%
import csv
import tweepy

#import mysql.connector
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

D_tweet = []
D_candidato = []
D_fecha_creacion = []
D_numero_favoritos = []
D_numero_retweets = []

for status in tweepy.Cursor(api.user_timeline, screen_name = 'sergio_fajardo', exclude_replies = True, include_rts = False, tweet_mode="extended").items(1000):
    screen_name = "Sergio Fajardo"
    full_text = status.full_text
    created_at = status.created_at
    favorite_count = status.favorite_count
    retweet_count = status.retweet_count

    D_tweet.append(full_text)
    D_candidato.append(screen_name)
    D_fecha_creacion.append(created_at)
    D_numero_favoritos.append(favorite_count)
    D_numero_retweets.append(retweet_count)


if len(D_tweet) > 0 : 
        with open('Sergio Fajardo.csv', 'w', newline='',encoding="utf-8") as f:
            fieldnames = ['tweet', 'candidato', 'fecha_creacion', 'numero_favoritos', 'numero_retweets']
            writer = csv.DictWriter(f,delimiter= ",", fieldnames=fieldnames)
            writer.writeheader()
            for i, text in enumerate(D_tweet):
                 writer.writerow({'tweet': D_tweet[i], 'candidato' : D_candidato[i], 'fecha_creacion' : D_fecha_creacion[i], 'numero_favoritos': D_numero_favoritos[i], 'numero_retweets' :D_numero_retweets[i]})



print("fin")
#Captura tomada en 03 de febrero 5:40 pm
# Out:
# fin

# %%
import csv
import tweepy

#import mysql.connector
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

D_tweet = []
D_candidato = []
D_fecha_creacion = []
D_numero_favoritos = []
D_numero_retweets = []

for status in tweepy.Cursor(api.user_timeline, screen_name = 'juanmanuelgalan', exclude_replies = True, include_rts = False, tweet_mode="extended").items(1000):
    screen_name = "Juan Manuel Galán"
    full_text = status.full_text
    created_at = status.created_at
    favorite_count = status.favorite_count
    retweet_count = status.retweet_count

    D_tweet.append(full_text)
    D_candidato.append(screen_name)
    D_fecha_creacion.append(created_at)
    D_numero_favoritos.append(favorite_count)
    D_numero_retweets.append(retweet_count)


if len(D_tweet) > 0 : 
        with open('Juan Manuel Galán.csv', 'w', newline='',encoding="utf-8") as f:
            fieldnames = ['tweet', 'candidato', 'fecha_creacion', 'numero_favoritos', 'numero_retweets']
            writer = csv.DictWriter(f,delimiter= ",", fieldnames=fieldnames)
            writer.writeheader()
            for i, text in enumerate(D_tweet):
                 writer.writerow({'tweet': D_tweet[i], 'candidato' : D_candidato[i], 'fecha_creacion' : D_fecha_creacion[i], 'numero_favoritos': D_numero_favoritos[i], 'numero_retweets' :D_numero_retweets[i]})



print("fin")
#Captura tomada en 03 de febrero 5:40 pm
# Out:
# fin
