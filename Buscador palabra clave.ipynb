# %%
import tweepy
import pymysql
import tweepy
import json
import mysql.connector
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
keyword = input("Enter Keyweord/Tag to search about: ")
cantidad= int(input("Enter how many tweets to search: "))
n_f_min= 10
for tweet in tweepy.Cursor(api.search_tweets, q=keyword).items(cantidad):
    if tweet.retweet_count > n_f_min:
        
            
    
        print("El texto es: \n" + tweet.text)
        print("la feacha de creacion: \n" +str(tweet.created_at))
        print("Numero de favoritos: " + str(tweet.favorite_count))
        print("El numero de retweets: " + str(tweet.retweet_count))
        print("Las cordenadas del tweet: " + str(tweet.coordinates))
        print("Usuario: " + str(tweet.user.screen_name))
        
        
        usuario= tweet.user.screen_name
        tweet= tweet.text
        numero_retweet= tweet.retweet_count
        numero_favoritos= tweet.favorite_count
        fecha_creaccion= tweet.created_at
        
        conexion1=mysql.connector.connect(host="localhost",user="root",port="3307",password="4aneYUBuG1JgfHa",database="prueba1")

        cursor1= conexion1.cursor()
        #cursor1.execute("show databases")
        #for base in cursor1:
        #print(base)    
        usuario= tweet.user.screen_name
        tweet= tweet.text
        #numero_retweet= tweet.retweet_count
        #numero_favoritos= tweet.favorite_count
        fecha_creaccion= tweet.created_at

        sql="insert into mct(usuario, tweet, fecha_creaccion) values (%s,%s,%s)"

        datos=(usuario, tweet, numero_retweet, numero_favoritos, fecha_creaccion)
        cursor1.execute(sql, datos)

conexion1.commit()
conexion1.close()
# Out:
# Enter Keyweord/Tag to search about:  @petrogustavo
# Enter how many tweets to search:  10
# El texto es:
# RT @ElQueLosDELATA: Soy hijo de un ingeniero,un empresario,pragmático,capitalista y de derecha, conocí a ricos comerciantes e industriales…
# la feacha de creacion:
# 2022-02-04 00:49:53+00:00
# Numero de favoritos: 0
# El numero de retweets: 1525
# Las cordenadas del tweet: None
# Usuario: pastusolibre
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-e7c3471a4a27> in <module>
#      29         usuario= tweet.user.screen_name
#      30         tweet= tweet.text
# ---> 31         numero_retweet= tweet.retweet_count
#      32         numero_favoritos= tweet.favorite_count
#      33         fecha_creaccion= tweet.created_at
#
# AttributeError: 'str' object has no attribute 'retweet_count'

# %%
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
keyword = input("Enter Keyweord/Tag to search about: ")
cantidad= int(input("Enter how many tweets to search: "))
n_f_min= 10
for tweet in tweepy.Cursor(api.search_tweets, q=keyword).items(cantidad):
    if tweet.retweet_count > n_f_min:
        
            
    
        print("El texto es: \n" + tweet.text)
        print("la feacha de creacion: \n" +str(tweet.created_at))
        print("Numero de favoritos: " + str(tweet.favorite_count))
        print("El numero de retweets: " + str(tweet.retweet_count))
        print("Las cordenadas del tweet: " + str(tweet.coordinates))
        print("Usuario: " + str(tweet.user.screen_name))
# Out:
# Enter Keyweord/Tag to search about:  @petrogustavo
# Enter how many tweets to search:  50
# El texto es:
# RT @DavidRacero: Todavía sigo leyendo las lamentaciones de los uribistas por el diálogo entre Petro y el Papa.
#
# @petrogustavo tiene toda l…
# la feacha de creacion:
# 2022-02-04 00:46:58+00:00
# Numero de favoritos: 0
# El numero de retweets: 600
# Las cordenadas del tweet: None
# Usuario: alfirezal05
# El texto es:
# RT @petrogustavo: ¿Cómo lograr una Colombia en Paz y una América en Paz?, tema de mi conversación con el ex jefe del gobierno español José…
# la feacha de creacion:
# 2022-02-04 00:46:57+00:00
# Numero de favoritos: 0
# El numero de retweets: 471
# Las cordenadas del tweet: None
# Usuario: Cami61257010
# El texto es:
# RT @CoachWilmarR: Fuerte mensaje de una patrullera de mi @PoliciaColombia a los viciosos #petrodrogos #petrozombies violadores de la 1a lín…
# la feacha de creacion:
# 2022-02-04 00:46:55+00:00
# Numero de favoritos: 0
# El numero de retweets: 98
# Las cordenadas del tweet: None
# Usuario: elvenua7
# El texto es:
# RT @petrogustavo: Hice el compromiso de no comentar públicamente mi conversación con el Papa Francisco del que ya he leído sus dos encíclic…
# la feacha de creacion:
# 2022-02-04 00:46:55+00:00
# Numero de favoritos: 0
# El numero de retweets: 1862
# Las cordenadas del tweet: None
# Usuario: dreamcolombi
# El texto es:
# RT @petrogustavo: ¿Cómo lograr una Colombia en Paz y una América en Paz?, tema de mi conversación con el ex jefe del gobierno español José…
# la feacha de creacion:
# 2022-02-04 00:46:55+00:00
# Numero de favoritos: 0
# El numero de retweets: 471
# Las cordenadas del tweet: None
# Usuario: jsrinconc
# El texto es:
# RT @HOLLMANMORRIS: #QuePena el odio que genera el recibimiento del Papa Francisco a @petrogustavo en algunos sectores de la prensa y la ext…
# la feacha de creacion:
# 2022-02-04 00:46:55+00:00
# Numero de favoritos: 0
# El numero de retweets: 712
# Las cordenadas del tweet: None
# Usuario: glorigenia
# El texto es:
# RT @mjoftalmo: Señor Petro: sería tan amable de explicar por qué en la Oficina de Prensa del Vaticano no aparece la tan cacareada audiencia…
# la feacha de creacion:
# 2022-02-04 00:46:55+00:00
# Numero de favoritos: 0
# El numero de retweets: 823
# Las cordenadas del tweet: None
# Usuario: TorresLJuanC
# El texto es:
# RT @petrogustavo: ¿Cómo lograr una Colombia en Paz y una América en Paz?, tema de mi conversación con el ex jefe del gobierno español José…
# la feacha de creacion:
# 2022-02-04 00:46:54+00:00
# Numero de favoritos: 0
# El numero de retweets: 471
# Las cordenadas del tweet: None
# Usuario: ernesto1972m6
# El texto es:
# RT @sebastianplld: @petrogustavo Con el rey del pop.
#
# Esto se está saliendo de control.
# #PetroShop https://t.co/Et9a0ZI1sP
# la feacha de creacion:
# 2022-02-04 00:46:53+00:00
# Numero de favoritos: 0
# El numero de retweets: 484
# Las cordenadas del tweet: None
# Usuario: Autonomo16
# El texto es:
# RT @petrogustavo: ¿Cómo lograr una Colombia en Paz y una América en Paz?, tema de mi conversación con el ex jefe del gobierno español José…
# la feacha de creacion:
# 2022-02-04 00:46:53+00:00
# Numero de favoritos: 0
# El numero de retweets: 471
# Las cordenadas del tweet: None
# Usuario: Ricardo03036120
# El texto es:
# RT @petrogustavo: ¿Cómo lograr una Colombia en Paz y una América en Paz?, tema de mi conversación con el ex jefe del gobierno español José…
# la feacha de creacion:
# 2022-02-04 00:46:52+00:00
# Numero de favoritos: 0
# El numero de retweets: 471
# Las cordenadas del tweet: None
# Usuario: uribevideos
# El texto es:
# RT @GustavoBolivar: @GloriaFlorezSI @RicardoparraII @IvanDuque @petrogustavo @AABenedetti @DavidRacero @MafeCarrascal @ammejiaaguado @Aliri…
# la feacha de creacion:
# 2022-02-04 00:46:50+00:00
# Numero de favoritos: 0
# El numero de retweets: 17
# Las cordenadas del tweet: None
# Usuario: Alex76753373
# El texto es:
# RT @AABenedetti: Ahora resulta que ir donde el Papa es malo. ¿Será que a los periodistas que no les gustó la visita de @petrogustavo al Pap…
# la feacha de creacion:
# 2022-02-04 00:46:49+00:00
# Numero de favoritos: 0
# El numero de retweets: 1122
# Las cordenadas del tweet: None
# Usuario: J_lazz
# El texto es:
# RT @joaltejada: La entrevista de @petrogustavo con el Papa Francisco en el Vaticano tiene un significado geopolítico muy potente. Es un men…
# la feacha de creacion:
# 2022-02-04 00:46:44+00:00
# Numero de favoritos: 0
# El numero de retweets: 969
# Las cordenadas del tweet: None
# Usuario: Valeroabdul
# El texto es:
# RT @KUIJOTES: @petrogustavo Importante que sepan cómo VOTAR y no BOTAR su VOTO. https://t.co/I1qLyFLWiF
# la feacha de creacion:
# 2022-02-04 00:46:43+00:00
# Numero de favoritos: 0
# El numero de retweets: 104
# Las cordenadas del tweet: None
# Usuario: eleutheros56
# El texto es:
# RT @liliebb: @mjoftalmo @petrogustavo @GustavoBolivar Por que para mi; esa fue una cortina de humo que utilizo, para desviar la atención (i…
# la feacha de creacion:
# 2022-02-04 00:46:41+00:00
# Numero de favoritos: 0
# El numero de retweets: 33
# Las cordenadas del tweet: None
# Usuario: rmogollon55
# El texto es:
# RT @petrogustavo: ¿Cómo lograr una Colombia en Paz y una América en Paz?, tema de mi conversación con el ex jefe del gobierno español José…
# la feacha de creacion:
# 2022-02-04 00:46:41+00:00
# Numero de favoritos: 0
# El numero de retweets: 471
# Las cordenadas del tweet: None
# Usuario: LaceraRafael
# El texto es:
# RT @joseshidarta: Mientras @petrogustavo se reúne con su santidad EL PAPA,al drogo @FicoGutierrez no lo recibe ni el padre CHUCHO.
# la feacha de creacion:
# 2022-02-04 00:46:40+00:00
# Numero de favoritos: 0
# El numero de retweets: 120
# Las cordenadas del tweet: None
# Usuario: gypsypao
# El texto es:
# RT @paressa16: .@GustavoBolivar, el que hizo que dos jóvenes se suicidaran, hablando de "bendiciones" pero CON UN MONTAJE!
# 🤣🤣🤣🤣🤣🤣🤣🤣 Todo lo…
# la feacha de creacion:
# 2022-02-04 00:46:40+00:00
# Numero de favoritos: 0
# El numero de retweets: 40
# Las cordenadas del tweet: None
# Usuario: goadm
# El texto es:
# RT @AlexKleinO: La foto de @petrogustavo con el papa es falsa, pero las fotos de @IvanDuque con el Ñeñe Hernández y el piloto del cartel de…
# la feacha de creacion:
# 2022-02-04 00:46:39+00:00
# Numero de favoritos: 0
# El numero de retweets: 2434
# Las cordenadas del tweet: None
# Usuario: EFRJK
# El texto es:
# RT @petrogustavo: Le regalé al Papa Francisco un libro que precisamente muestra con estadística, como el país tiene una de las peores inequ…
# la feacha de creacion:
# 2022-02-04 00:46:39+00:00
# Numero de favoritos: 0
# El numero de retweets: 1101
# Las cordenadas del tweet: None
# Usuario: ElProfe46254611
# El texto es:
# RT @YASS31547764: AYER SEGÚN LOS #PetroShop DE @GustavoBolivar @petrogustavo LLENO LA PLAZA DEL VATICANO @Pontifex 🤣🤣 https://t.co/C5mFcgsa…
# la feacha de creacion:
# 2022-02-04 00:46:37+00:00
# Numero de favoritos: 0
# El numero de retweets: 251
# Las cordenadas del tweet: None
# Usuario: clatsai
# El texto es:
# RT @petrogustavo: La existencia de la hambruna en las grandes ciudades, es el gran pecado nacional, Duque. No puede haber mayor desidia del…
# la feacha de creacion:
# 2022-02-04 00:46:36+00:00
# Numero de favoritos: 0
# El numero de retweets: 1345
# Las cordenadas del tweet: None
# Usuario: calisrafa2
# El texto es:
# RT @petrogustavo: ¿Cómo lograr una Colombia en Paz y una América en Paz?, tema de mi conversación con el ex jefe del gobierno español José…
# la feacha de creacion:
# 2022-02-04 00:46:34+00:00
# Numero de favoritos: 0
# El numero de retweets: 471
# Las cordenadas del tweet: None
# Usuario: edwincas1975
# El texto es:
# RT @ElQueLosDELATA: Soy hijo de un ingeniero,un empresario,pragmático,capitalista y de derecha, conocí a ricos comerciantes e industriales…
# la feacha de creacion:
# 2022-02-04 00:46:33+00:00
# Numero de favoritos: 0
# El numero de retweets: 1517
# Las cordenadas del tweet: None
# Usuario: SirVaillant
# El texto es:
# RT @andresportillo_: Gravísima denuncia hace @AndresPastrana_. En su paso por Madrid, @petrogustavo se reúne con el presidente de INDRA, la…
# la feacha de creacion:
# 2022-02-04 00:46:32+00:00
# Numero de favoritos: 0
# El numero de retweets: 494
# Las cordenadas del tweet: None
# Usuario: giraldocarlos

# %%
import tweepy
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
keyword = input("Enter Keyweord/Tag to search about: ")
cantidad= int(input("Enter how many tweets to search: "))
n_f_min= 10
for tweet in tweepy.Cursor(api.search_tweets, q=keyword).items(cantidad):
    if tweet.retweet_count > n_f_min:
        
            
    
        print("El texto es: \n" + tweet.text)
        print("la feacha de creacion: \n" +str(tweet.created_at))
        print("Numero de favoritos: " + str(tweet.favorite_count))
        print("El numero de retweets: " + str(tweet.retweet_count))
        print("Las cordenadas del tweet: " + str(tweet.coordinates))
        print("Usuario: " + str(tweet.user.screen_name))
# Out:
# Enter Keyweord/Tag to search about:  ZULUAGA
# Enter how many tweets to search:  30
# El texto es:
# RT @silvioravel: Sres @CorteSupremaJ  Hacer verdadera justicia como en el caso del hijo de Zuluaga no es sólo declarar inocente al inculpad…
# la feacha de creacion:
# 2021-11-30 04:48:31+00:00
# Numero de favoritos: 0
# El numero de retweets: 340
# Las cordenadas del tweet: None
# Usuario: OscarOr27297762
# El texto es:
# RT @JuanLozano_R: Lástima grande que el General Mora no hubiera hablado antes.
# Lástima grande que Oscar Iván Zuluaga no hubiera hablado ant…
# la feacha de creacion:
# 2021-11-30 04:48:17+00:00
# Numero de favoritos: 0
# El numero de retweets: 2102
# Las cordenadas del tweet: None
# Usuario: adrianalucia61
# El texto es:
# RT @LaKrupskaya2101: De los creadores de “váyase a vivir a Cuba-Venezuela”, llega la perla de: “si tanto le molesta la alianza con Luis Pér…
# la feacha de creacion:
# 2021-11-30 04:48:02+00:00
# Numero de favoritos: 0
# El numero de retweets: 26
# Las cordenadas del tweet: None
# Usuario: FabianMazo
# El texto es:
# RT @eltajalapiz: “FRANKENSTEIN ZULUAGA"
#
# En @lanuevaprensaco https://t.co/OeTi8nFv3B
# la feacha de creacion:
# 2021-11-30 04:47:06+00:00
# Numero de favoritos: 0
# El numero de retweets: 62
# Las cordenadas del tweet: None
# Usuario: OIRAMNOHJ
# El texto es:
# RT @eltajalapiz: “FRANKENSTEIN ZULUAGA"
#
# En @lanuevaprensaco https://t.co/OeTi8nFv3B
# la feacha de creacion:
# 2021-11-30 04:46:21+00:00
# Numero de favoritos: 0
# El numero de retweets: 62
# Las cordenadas del tweet: None
# Usuario: EsperanzaDuqueC
# El texto es:
# RT @petrogustavo: Mi debate con Alejandro Gaviria y con Oscar Ivan Zuluaga. En este tipo de debates con competidores y públicos hostiles a…
# la feacha de creacion:
# 2021-11-30 04:46:11+00:00
# Numero de favoritos: 0
# El numero de retweets: 6097
# Las cordenadas del tweet: None
# Usuario: juanKArevaloP
# El texto es:
# RT @Eclides3: Si Uribe le tiene miedo a un candidato inteligente como Petro, es porque lo prefiere bruto e ignorante como Duque o Zuluaga.
# la feacha de creacion:
# 2021-11-30 04:44:17+00:00
# Numero de favoritos: 0
# El numero de retweets: 398
# Las cordenadas del tweet: None
# Usuario: diegofer21marin
# El texto es:
# RT @LaKrupskaya2101: De los creadores de “váyase a vivir a Cuba-Venezuela”, llega la perla de: “si tanto le molesta la alianza con Luis Pér…
# la feacha de creacion:
# 2021-11-30 04:44:00+00:00
# Numero de favoritos: 0
# El numero de retweets: 26
# Las cordenadas del tweet: None
# Usuario: nolescreo_
# El texto es:
# RT @jorgearteaga888: señor @OIZuluaga :
# Ésta es una Petición OFICIAL del Uribismo, y usted lo sabe bien que ud NO nos representa a la Mayor…
# la feacha de creacion:
# 2021-11-30 04:42:32+00:00
# Numero de favoritos: 0
# El numero de retweets: 242
# Las cordenadas del tweet: None
# Usuario: PIP01P
# El texto es:
# RT @silvioravel: Sres @CorteSupremaJ  Hacer verdadera justicia como en el caso del hijo de Zuluaga no es sólo declarar inocente al inculpad…
# la feacha de creacion:
# 2021-11-30 04:40:28+00:00
# Numero de favoritos: 0
# El numero de retweets: 340
# Las cordenadas del tweet: None
# Usuario: prtas19
# El texto es:
# RT @CARLOSFMEJIA: Óscar Iván Zuluaga proclamado oficialmente, Candidato a la Presidencia de la República en la Convención del @CeDemocratic…
# la feacha de creacion:
# 2021-11-30 04:40:24+00:00
# Numero de favoritos: 0
# El numero de retweets: 36
# Las cordenadas del tweet: None
# Usuario: amparomeza
# El texto es:
# RT @ivanwilches3: @ernestomaciast @AlvaroUribeVel Ya logró su objetivo de imponer a Zuluaga, me imagino que el tibio le ofreció esta vida y…
# la feacha de creacion:
# 2021-11-30 04:39:16+00:00
# Numero de favoritos: 0
# El numero de retweets: 25
# Las cordenadas del tweet: None
# Usuario: Claudia012062
# El texto es:
# RT @jorgearteaga888: señor @OIZuluaga :
# Ésta es una Petición OFICIAL del Uribismo, y usted lo sabe bien que ud NO nos representa a la Mayor…
# la feacha de creacion:
# 2021-11-30 04:34:23+00:00
# Numero de favoritos: 0
# El numero de retweets: 242
# Las cordenadas del tweet: None
# Usuario: 666Berm
# El texto es:
# RT @jorgearteaga888: señor @OIZuluaga :
# Ésta es una Petición OFICIAL del Uribismo, y usted lo sabe bien que ud NO nos representa a la Mayor…
# la feacha de creacion:
# 2021-11-30 04:33:07+00:00
# Numero de favoritos: 0
# El numero de retweets: 242
# Las cordenadas del tweet: None
# Usuario: SamuVal777
# El texto es:
# RT @JackDeLaConcha: El Doctor Óscar Iván Zuluaga, por sugerencia del presidente eterno, se hace la keratina de Epa Colombia.  "La idea es m…
# la feacha de creacion:
# 2021-11-30 04:33:05+00:00
# Numero de favoritos: 0
# El numero de retweets: 249
# Las cordenadas del tweet: None
# Usuario: lstivensl
# El texto es:
# RT @jorgearteaga888: señor @OIZuluaga :
# Ésta es una Petición OFICIAL del Uribismo, y usted lo sabe bien que ud NO nos representa a la Mayor…
# la feacha de creacion:
# 2021-11-30 04:31:23+00:00
# Numero de favoritos: 0
# El numero de retweets: 242
# Las cordenadas del tweet: None
# Usuario: Milobeta
# El texto es:
# RT @jorgearteaga888: señor @OIZuluaga :
# Ésta es una Petición OFICIAL del Uribismo, y usted lo sabe bien que ud NO nos representa a la Mayor…
# la feacha de creacion:
# 2021-11-30 04:30:23+00:00
# Numero de favoritos: 0
# El numero de retweets: 242
# Las cordenadas del tweet: None
# Usuario: wilzer1984_faz

# %%
import tweepy
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
keyword = input("Enter Keyweord/Tag to search about: ")
cantidad= int(input("Enter how many tweets to search: "))
n_f_min= 10
for tweet in tweepy.Cursor(api.search_tweets, q=keyword).items(cantidad):
    if tweet.retweet_count > n_f_min:
        
            
    
        print("El texto es: \n" + tweet.text)
        print("la feacha de creacion: \n" +str(tweet.created_at))
        print("Numero de favoritos: " + str(tweet.favorite_count))
        print("El numero de retweets: " + str(tweet.retweet_count))
        print("Las cordenadas del tweet: " + str(tweet.coordinates))
        print("Usuario: " + str(tweet.user.screen_name))

# %%
from __future__ import print_function
import tweepy
import json
import MySQLdb 
from dateutil import parser

WORDS = ['#bigdata', '#AI', '#datascience', '#machinelearning', '#ml', '#iot']

CONSUMER_KEY = "KEY"
CONSUMER_SECRET = "SECRET"
ACCESS_TOKEN = "TOKEN"
ACCESS_TOKEN_SECRET = "TOKEN_SECRET"

HOST = "YOUR_DATABASE_HOST"
USER = "YOUR_DATABASE_USER"
PASSWD = "YOUR_DATABASE_PASSWORD"
DATABASE = "YOUR_DATABASE"

# This function takes the 'created_at', 'text', 'screen_name' and 'tweet_id' and stores it
# into a MySQL database
def store_data(created_at, text, screen_name, tweet_id):
    db=MySQLdb.connect(host=HOST, user=USER, passwd=PASSWD, db=DATABASE, charset="utf8")
    cursor = db.cursor()
    insert_query = "INSERT INTO twitter (tweet_id, screen_name, created_at, text) VALUES (%s, %s, %s, %s)"
    cursor.execute(insert_query, (tweet_id, screen_name, created_at, text))
    db.commit()
    cursor.close()
    db.close()
    return

class StreamListener(tweepy.StreamListener):    
    #This is a class provided by tweepy to access the Twitter Streaming API. 

    def on_connect(self):
        # Called initially to connect to the Streaming API
        print("You are now connected to the streaming API.")
 
    def on_error(self, status_code):
        # On error - if an error occurs, display the error / status code
        print('An Error has occured: ' + repr(status_code))
        return False
 
    def on_data(self, data):
        #This is the meat of the script...it connects to your mongoDB and stores the tweet
        try:
           # Decode the JSON from Twitter
            datajson = json.loads(data)
            
            #grab the wanted data from the Tweet
            text = datajson['text']
            screen_name = datajson['user']['screen_name']
            tweet_id = datajson['id']
            created_at = parser.parse(datajson['created_at']) 

            #print out a message to the screen that we have collected a tweet
            print("Tweet collected at " + str(created_at))
            
            #insert the data into the MySQL database
            store_data(created_at, text, screen_name, tweet_id)
        
        except Exception as e:
           print(e)

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
#Set up the listener. The 'wait_on_rate_limit=True' is needed to help with Twitter API rate limiting.
listener = StreamListener(api=tweepy.API(wait_on_rate_limit=True)) 
streamer = tweepy.Stream(auth=auth, listener=listener)
print("Tracking: " + str(WORDS))
streamer.filter(track=WORDS)
