# %%
import csv
import tweepy

#import mysql.connector
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

D_usuario = []
D_tweet = []
D_numero_retweet = []
D_numero_favoritos = []
D_fecha_creaccion = []

keyword = input("Enter Keyweord/Tag to search about: ")
cantidad= int(input("Enter how many tweets to search: "))
n_f_min= 10
for tweet in tweepy.Cursor(api.search_tweets, q=keyword).items(cantidad):
    if tweet.retweet_count > n_f_min:
        screen_name= tweet.user.screen_name
        full_text = tweet.text
        retweet_count = tweet.retweet_count
        favorite_count = tweet.favorite_count
        created_at = tweet.created_at

        D_usuario.append(screen_name)
        D_tweet.append(full_text)
        D_numero_retweet.append(retweet_count)
        D_numero_favoritos.append(favorite_count)
        D_fecha_creaccion.append(created_at)
            
    
        #print("El texto es: \n" + tweet.text)
        #print("la feacha de creacion: \n" +str(tweet.created_at))
        #print("Numero de favoritos: " + str(tweet.favorite_count))
        #print("El numero de retweets: " + str(tweet.retweet_count))
        #print("Las cordenadas del tweet: " + str(tweet.coordinates))
        #print("Usuario: " + str(tweet.user.screen_name))

if len(D_tweet) > 0 : 
        with open('Menciones.petroghgf.csv', 'w', newline='',encoding="utf-8") as f:
            fieldnames = ['usuario', 'tweet', 'numero_retweet', 'numero_favoritos', 'fecha_creaccion']
            writer = csv.DictWriter(f,delimiter= ",", fieldnames=fieldnames)
            writer.writeheader()
            for i, text in enumerate(D_tweet):
                 writer.writerow({'usuario':  D_usuario[i], 'tweet' : D_tweet[i], 'numero_retweet' : D_numero_retweet[i], 'numero_favoritos': D_numero_favoritos[i], 'fecha_creaccion' :D_fecha_creaccion[i]})



print("fin")

#Captura tomada en 04 de febrero 2:55 pm
# Out:
# Enter Keyweord/Tag to search about:  1
# Enter how many tweets to search:  5000
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-2-46d269551b18> in <module>
#      20 cantidad= int(input("Enter how many tweets to search: "))
#      21 n_f_min= 10
# ---> 22 for tweet in tweepy.Cursor(api.search_tweets, q=keyword).items(cantidad):
#      23     if tweet.retweet_count > n_f_min:
#      24         screen_name= tweet.user.screen_name
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
#     287             while len(self.current_page) == 0:
#     288                 self.current_page = next(self.page_iterator)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     165
#     166         if self.index >= len(self.results) - 1:
# --> 167             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     168
#     169             model = ModelParser().parse(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\api.py in search_tweets(self, q, **kwargs)
#    1266         https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/api-reference/get-search-tweets
#    1267         """
# -> 1268         return self.request(
#    1269             'GET', 'search/tweets', endpoint_parameters=(
#    1270                 'q', 'geocode', 'lang', 'locale', 'result_type', 'count',
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     261                 raise NotFound(resp)
#     262             if resp.status_code == 429:
# --> 263                 raise TooManyRequests(resp)
#     264             if resp.status_code >= 500:
#     265                 raise TwitterServerError(resp)
#
# TooManyRequests: 429 Too Many Requests
# 88 - Rate limit exceeded

# %%
import csv
import tweepy

#import mysql.connector
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

D_usuario = []
D_tweet = []
D_numero_retweet = []
D_numero_favoritos = []
D_fecha_creaccion = []

keyword = input("Enter Keyweord/Tag to search about: ")
cantidad= int(input("Enter how many tweets to search: "))
n_f_min= 10
for tweet in tweepy.Cursor(api.search_tweets, q=keyword).items(cantidad):
    if tweet.retweet_count > n_f_min:
        screen_name= tweet.user.screen_name
        full_text = tweet.text
        retweet_count = tweet.retweet_count
        favorite_count = tweet.favorite_count
        created_at = tweet.created_at

        D_usuario.append(screen_name)
        D_tweet.append(full_text)
        D_numero_retweet.append(retweet_count)
        D_numero_favoritos.append(favorite_count)
        D_fecha_creaccion.append(created_at)
            
    
        #print("El texto es: \n" + tweet.text)
        #print("la feacha de creacion: \n" +str(tweet.created_at))
        #print("Numero de favoritos: " + str(tweet.favorite_count))
        #print("El numero de retweets: " + str(tweet.retweet_count))
        #print("Las cordenadas del tweet: " + str(tweet.coordinates))
        #print("Usuario: " + str(tweet.user.screen_name))

if len(D_tweet) > 0 : 
        with open('Menciones.fico2.csv', 'w', newline='',encoding="utf-8") as f:
            fieldnames = ['usuario', 'tweet', 'numero_retweet', 'numero_favoritos', 'fecha_creaccion']
            writer = csv.DictWriter(f,delimiter= ",", fieldnames=fieldnames)
            writer.writeheader()
            for i, text in enumerate(D_tweet):
                 writer.writerow({'usuario':  D_usuario[i], 'tweet' : D_tweet[i], 'numero_retweet' : D_numero_retweet[i], 'numero_favoritos': D_numero_favoritos[i], 'fecha_creaccion' :D_fecha_creaccion[i]})



print("fin")
#Captura tomada en 04 de febrero 2:55 pm
# Out:
# Enter Keyweord/Tag to search about:  Fico Gutierrez
# Enter how many tweets to search:  100
# fin

# %%
import csv
import tweepy

#import mysql.connector
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

D_usuario = []
D_tweet = []
D_numero_retweet = []
D_numero_favoritos = []
D_fecha_creaccion = []

keyword = input("Enter Keyweord/Tag to search about: ")
cantidad= int(input("Enter how many tweets to search: "))
n_f_min= 10
for tweet in tweepy.Cursor(api.search_tweets, q=keyword).items(cantidad):
    if tweet.retweet_count > n_f_min:
        screen_name= tweet.user.screen_name
        full_text = tweet.text
        retweet_count = tweet.retweet_count
        favorite_count = tweet.favorite_count
        created_at = tweet.created_at

        D_usuario.append(screen_name)
        D_tweet.append(full_text)
        D_numero_retweet.append(retweet_count)
        D_numero_favoritos.append(favorite_count)
        D_fecha_creaccion.append(created_at)
            
    
        #print("El texto es: \n" + tweet.text)
        #print("la feacha de creacion: \n" +str(tweet.created_at))
        #print("Numero de favoritos: " + str(tweet.favorite_count))
        #print("El numero de retweets: " + str(tweet.retweet_count))
        #print("Las cordenadas del tweet: " + str(tweet.coordinates))
        #print("Usuario: " + str(tweet.user.screen_name))

if len(D_tweet) > 0 : 
        with open('Menciones.Gaviria.csv', 'w', newline='',encoding="utf-8") as f:
            fieldnames = ['usuario', 'tweet', 'numero_retweet', 'numero_favoritos', 'fecha_creaccion']
            writer = csv.DictWriter(f,delimiter= ",", fieldnames=fieldnames)
            writer.writeheader()
            for i, text in enumerate(D_tweet):
                 writer.writerow({'usuario':  D_usuario[i], 'tweet' : D_tweet[i], 'numero_retweet' : D_numero_retweet[i], 'numero_favoritos': D_numero_favoritos[i], 'fecha_creaccion' :D_fecha_creaccion[i]})



print("fin")
#Captura tomada en 04 de febrero 2:55 pm
# Out:
# Enter Keyweord/Tag to search about:  Alejandro Gaviria
# Enter how many tweets to search:  100
# fin

# %%
import csv
import tweepy

#import mysql.connector
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

D_usuario = []
D_tweet = []
D_numero_retweet = []
D_numero_favoritos = []
D_fecha_creaccion = []

keyword = input("Enter Keyweord/Tag to search about: ")
cantidad= int(input("Enter how many tweets to search: "))
n_f_min= 10
for tweet in tweepy.Cursor(api.search_tweets, q=keyword).items(cantidad):
    if tweet.retweet_count > n_f_min:
        screen_name= tweet.user.screen_name
        full_text = tweet.text
        retweet_count = tweet.retweet_count
        favorite_count = tweet.favorite_count
        created_at = tweet.created_at

        D_usuario.append(screen_name)
        D_tweet.append(full_text)
        D_numero_retweet.append(retweet_count)
        D_numero_favoritos.append(favorite_count)
        D_fecha_creaccion.append(created_at)
            
    
        #print("El texto es: \n" + tweet.text)
        #print("la feacha de creacion: \n" +str(tweet.created_at))
        #print("Numero de favoritos: " + str(tweet.favorite_count))
        #print("El numero de retweets: " + str(tweet.retweet_count))
        #print("Las cordenadas del tweet: " + str(tweet.coordinates))
        #print("Usuario: " + str(tweet.user.screen_name))

if len(D_tweet) > 0 : 
        with open('Menciones.Francia.csv', 'w', newline='',encoding="utf-8") as f:
            fieldnames = ['usuario', 'tweet', 'numero_retweet', 'numero_favoritos', 'fecha_creaccion']
            writer = csv.DictWriter(f,delimiter= ",", fieldnames=fieldnames)
            writer.writeheader()
            for i, text in enumerate(D_tweet):
                 writer.writerow({'usuario':  D_usuario[i], 'tweet' : D_tweet[i], 'numero_retweet' : D_numero_retweet[i], 'numero_favoritos': D_numero_favoritos[i], 'fecha_creaccion' :D_fecha_creaccion[i]})



print("fin")
#Captura tomada en 04 de febrero 2:55 pm
# Out:
# Enter Keyweord/Tag to search about:  francia marquez
# Enter how many tweets to search:  100
# fin

# %%
import csv
import tweepy

#import mysql.connector
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

D_usuario = []
D_tweet = []
D_numero_retweet = []
D_numero_favoritos = []
D_fecha_creaccion = []

keyword = input("Enter Keyweord/Tag to search about: ")
cantidad= int(input("Enter how many tweets to search: "))
n_f_min= 10
for tweet in tweepy.Cursor(api.search_tweets, q=keyword).items(cantidad):
    if tweet.retweet_count > n_f_min:
        screen_name= tweet.user.screen_name
        full_text = tweet.text
        retweet_count = tweet.retweet_count
        favorite_count = tweet.favorite_count
        created_at = tweet.created_at

        D_usuario.append(screen_name)
        D_tweet.append(full_text)
        D_numero_retweet.append(retweet_count)
        D_numero_favoritos.append(favorite_count)
        D_fecha_creaccion.append(created_at)
            
    
        #print("El texto es: \n" + tweet.text)
        #print("la feacha de creacion: \n" +str(tweet.created_at))
        #print("Numero de favoritos: " + str(tweet.favorite_count))
        #print("El numero de retweets: " + str(tweet.retweet_count))
        #print("Las cordenadas del tweet: " + str(tweet.coordinates))
        #print("Usuario: " + str(tweet.user.screen_name))

if len(D_tweet) > 0 : 
        with open('Menciones.Rodolfo.csv', 'w', newline='',encoding="utf-8") as f:
            fieldnames = ['usuario', 'tweet', 'numero_retweet', 'numero_favoritos', 'fecha_creaccion']
            writer = csv.DictWriter(f,delimiter= ",", fieldnames=fieldnames)
            writer.writeheader()
            for i, text in enumerate(D_tweet):
                 writer.writerow({'usuario':  D_usuario[i], 'tweet' : D_tweet[i], 'numero_retweet' : D_numero_retweet[i], 'numero_favoritos': D_numero_favoritos[i], 'fecha_creaccion' :D_fecha_creaccion[i]})



print("fin")
#Captura tomada en 04 de febrero 2:55 pm
# Out:
# Enter Keyweord/Tag to search about:  rodolfo hernandez
# Enter how many tweets to search:  100
# fin

# %%
import csv
import tweepy

#import mysql.connector
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

D_usuario = []
D_tweet = []
D_numero_retweet = []
D_numero_favoritos = []
D_fecha_creaccion = []

keyword = input("Enter Keyweord/Tag to search about: ")
cantidad= int(input("Enter how many tweets to search: "))
n_f_min= 10
for tweet in tweepy.Cursor(api.search_tweets, q=keyword).items(cantidad):
    if tweet.retweet_count > n_f_min:
        screen_name= tweet.user.screen_name
        full_text = tweet.text
        retweet_count = tweet.retweet_count
        favorite_count = tweet.favorite_count
        created_at = tweet.created_at

        D_usuario.append(screen_name)
        D_tweet.append(full_text)
        D_numero_retweet.append(retweet_count)
        D_numero_favoritos.append(favorite_count)
        D_fecha_creaccion.append(created_at)
            
    
        #print("El texto es: \n" + tweet.text)
        #print("la feacha de creacion: \n" +str(tweet.created_at))
        #print("Numero de favoritos: " + str(tweet.favorite_count))
        #print("El numero de retweets: " + str(tweet.retweet_count))
        #print("Las cordenadas del tweet: " + str(tweet.coordinates))
        #print("Usuario: " + str(tweet.user.screen_name))

if len(D_tweet) > 0 : 
        with open('Menciones.Fajardo2.csv', 'w', newline='',encoding="utf-8") as f:
            fieldnames = ['usuario', 'tweet', 'numero_retweet', 'numero_favoritos', 'fecha_creaccion']
            writer = csv.DictWriter(f,delimiter= ",", fieldnames=fieldnames)
            writer.writeheader()
            for i, text in enumerate(D_tweet):
                 writer.writerow({'usuario':  D_usuario[i], 'tweet' : D_tweet[i], 'numero_retweet' : D_numero_retweet[i], 'numero_favoritos': D_numero_favoritos[i], 'fecha_creaccion' :D_fecha_creaccion[i]})



print("fin")
#Captura tomada en 05 de febrero 7:27 am
# Out:
# Enter Keyweord/Tag to search about:  sergio fajardo
# Enter how many tweets to search:  100
# fin

# %%
import csv
import tweepy

#import mysql.connector
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

D_usuario = []
D_tweet = []
D_numero_retweet = []
D_numero_favoritos = []
D_fecha_creaccion = []

keyword = input("Enter Keyweord/Tag to search about: ")
cantidad= int(input("Enter how many tweets to search: "))
n_f_min= 10
for tweet in tweepy.Cursor(api.search_tweets, q=keyword).items(cantidad):
    if tweet.retweet_count > n_f_min:
        screen_name= tweet.user.screen_name
        full_text = tweet.text
        retweet_count = tweet.retweet_count
        favorite_count = tweet.favorite_count
        created_at = tweet.created_at

        D_usuario.append(screen_name)
        D_tweet.append(full_text)
        D_numero_retweet.append(retweet_count)
        D_numero_favoritos.append(favorite_count)
        D_fecha_creaccion.append(created_at)
            
    
        #print("El texto es: \n" + tweet.text)
        #print("la feacha de creacion: \n" +str(tweet.created_at))
        #print("Numero de favoritos: " + str(tweet.favorite_count))
        #print("El numero de retweets: " + str(tweet.retweet_count))
        #print("Las cordenadas del tweet: " + str(tweet.coordinates))
        #print("Usuario: " + str(tweet.user.screen_name))

if len(D_tweet) > 0 : 
        with open('Menciones.Galan.csv', 'w', newline='',encoding="utf-8") as f:
            fieldnames = ['usuario', 'tweet', 'numero_retweet', 'numero_favoritos', 'fecha_creaccion']
            writer = csv.DictWriter(f,delimiter= ",", fieldnames=fieldnames)
            writer.writeheader()
            for i, text in enumerate(D_tweet):
                 writer.writerow({'usuario':  D_usuario[i], 'tweet' : D_tweet[i], 'numero_retweet' : D_numero_retweet[i], 'numero_favoritos': D_numero_favoritos[i], 'fecha_creaccion' :D_fecha_creaccion[i]})



print("fin")
#Captura tomada en 05 de febrero 7:27 am
# Out:
# Enter Keyweord/Tag to search about:  juan manuel galan
# Enter how many tweets to search:  100
# fin
