# %%
import tweepy
import json
consumer_key= 'R5RdqdfKPUWgIdVzFCGOj5zxz'
consumer_secret= '0i6vgh02OPJHVTrW22aI1ScpsSj7Y55qOG03vP8RDh4FxtHEW4'
access_token= '1446921421465214977-lk60pjJEwpLcHuMD4fxaY7vBVoCFBu'
access_token_secret= 'MtnDwltywCcQwedwJXCla1Z0DYdRV1oKfZXRk5N4QWba8'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
user = api.get_user(screen_name= "OIZuluaga")
print("nombre de la persona", user.screen_name)
print("numero de seguidores", user.followers_count)
print("ID: ", user.id)
print("ID STR: ", user.id_str)
print(json.dumps(user._json, indent=1))
for friend in user.friends():
   print("friends", friend.screen_name)
# Out:
# nombre de la persona OIZuluaga
# numero de seguidores 811789
# ID:  262814659
# ID STR:  262814659
# {
#  "id": 262814659,
#  "id_str": "262814659",
#  "name": "\u00d3scar Iv\u00e1n Zuluaga",
#  "screen_name": "OIZuluaga",
#  "location": "",
#  "profile_location": null,
#  "description": "47 millones de motivos para trabajar por #UnaColombiaDistinta \ud83d\udcaa\ud83c\udffc\ud83c\udde8\ud83c\uddf4.",
#  "url": "https://t.co/6m1gPSrIgn",
#  "entities": {
#   "url": {
#    "urls": [
#     {
#      "url": "https://t.co/6m1gPSrIgn",
#      "expanded_url": "https://t.me/oscarivanzuluaga",
#      "display_url": "t.me/oscarivanzulua\u2026",
#      "indices": [
#       0,
#       23
#      ]
#     }
#    ]
#   },
#   "description": {
#    "urls": []
#   }
#  },
#  "protected": false,
#  "followers_count": 811789,
#  "friends_count": 779,
#  "listed_count": 1033,
#  "created_at": "Tue Mar 08 20:31:18 +0000 2011",
#  "favourites_count": 7649,
#  "utc_offset": null,
#  "time_zone": null,
#  "geo_enabled": true,
#  "verified": true,
#  "statuses_count": 29126,
#  "lang": null,
#  "status": {
#   "created_at": "Thu Feb 03 21:32:11 +0000 2022",
#   "id": 1489351030861176835,
#   "id_str": "1489351030861176835",
#   "text": "@jairora21054415 @CeDemocratico Gracias Jairo! \ud83d\udcaa\ud83c\udffc\ud83c\udde8\ud83c\uddf4",
#   "truncated": false,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "jairora21054415",
#      "name": "jairo rangel",
#      "id": 1332092769528115200,
#      "id_str": "1332092769528115200",
#      "indices": [
#       0,
#       16
#      ]
#     },
#     {
#      "screen_name": "CeDemocratico",
#      "name": "Centro Democr\u00e1tico",
#      "id": 1115440213,
#      "id_str": "1115440213",
#      "indices": [
#       17,
#       31
#      ]
#     }
#    ],
#    "urls": []
#   },
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "in_reply_to_status_id": 1489345865609269253,
#   "in_reply_to_status_id_str": "1489345865609269253",
#   "in_reply_to_user_id": 1332092769528115200,
#   "in_reply_to_user_id_str": "1332092769528115200",
#   "in_reply_to_screen_name": "jairora21054415",
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 0,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "es"
#  },
#  "contributors_enabled": false,
#  "is_translator": false,
#  "is_translation_enabled": false,
#  "profile_background_color": "FFFFFF",
#  "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#  "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#  "profile_background_tile": false,
#  "profile_image_url": "http://pbs.twimg.com/profile_images/996539767041986561/xSjJrWRJ_normal.jpg",
#  "profile_image_url_https": "https://pbs.twimg.com/profile_images/996539767041986561/xSjJrWRJ_normal.jpg",
#  "profile_banner_url": "https://pbs.twimg.com/profile_banners/262814659/1635190876",
#  "profile_link_color": "2CBFF5",
#  "profile_sidebar_border_color": "FFFFFF",
#  "profile_sidebar_fill_color": "DDEEF6",
#  "profile_text_color": "333333",
#  "profile_use_background_image": false,
#  "has_extended_profile": false,
#  "default_profile": false,
#  "default_profile_image": false,
#  "following": false,
#  "follow_request_sent": false,
#  "notifications": false,
#  "translator_type": "regular",
#  "withheld_in_countries": []
# }
# friends PonchoRente
# friends kayros_group
# friends VictorLopezT_
# friends JohnMiltonR_
# friends ANDRES_MOTTA
# friends marioherzam
# friends julya140912
# friends MonicaCerveraMu
# friends ARELYSHENAO
# friends ForerohElvira
# friends Enrique_GomezM
# friends aydeelizarazoc
# friends santiagopinzong
# friends henry_espriella
# friends DiegoJavOsorio
# friends EdwinValdesCqta
# friends oscardarioperez
# friends Hangelortizn
# friends miltonhav
# friends joseVcarreno101

# %%
import tweepy

# %%
user = api.get_user(screen_name= "@petrogustavo")
print("nombre de la persona", user.screen_name)
print("numero de seguidores", user.followers_count)
for friend in user.friends():
   print("friends", friend.screen_name)
# Out:
# nombre de la persona petrogustavo
# numero de seguidores 4382622
# friends joaltejada
# friends marialopezuribe
# friends ezbluebox
# friends IBetancourtCol
# friends MariaFdaCabal
# friends EGudynas
# friends andresarellanob
# friends FelizolaLiceth
# friends VillanueAle
# friends elatanquero
# friends Palabraspala
# friends PHJuvenilBogota
# friends delmarpizarro
# friends ParodyMallory
# friends _GillianMg
# friends agmethescaf
# friends urianaguariyu
# friends ALFREDOSAADEV
# friends PactoCol
# friends Catalinaperezp_
